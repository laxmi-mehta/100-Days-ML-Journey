# %% [markdown]
# Explains the difference between Bagging (Bootstrap Aggregating) and Random Forest ensemble methods.
#
# Shows how Random Forest improves bagging by adding random feature selection while building decision trees.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0 -0.809533  2.069449 -1.046424 -2.654487  1.721126       0
# 1 -0.296325  0.255573 -0.961100  0.705955 -0.599804       0
# 2  2.937005  0.997999  1.152129 -0.438639  0.610186       0
# 3 -0.020079  0.119145 -1.285767  0.127972 -0.403272       0
# 4  2.717600  1.066078  2.892686 -0.562828  1.242873       0

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
